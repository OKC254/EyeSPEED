# %% [markdown]
# # VisDrone Dataset

# %% [markdown]
# # Setup
#
# Pip install `ultralytics` and [dependencies](https://github.com/ultralytics/ultralytics/blob/main/requirements.txt) and check software and hardware.

# %%
# %pip install ultralytics  # install
from ultralytics import YOLO, checks, hub
checks()  # checks
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.5/78.2 GB disk)

# %% [markdown]
# # Start
#
# Login with your [API key](https://hub.ultralytics.com/settings?tab=api+keys), select your YOLO 🚀 model and start training!

# %%
hub.login('')

model = YOLO('https://hub.ultralytics.com/models/5fDjx7YastskNVPhXIME')
model.train()
# Out:
# Ultralytics HUB: New authentication successful ✅
# Ultralytics HUB: View model at https://hub.ultralytics.com/models/5fDjx7YastskNVPhXIME 🚀
# ...
# 100%|██████████| 49.7M/49.7M [00:00<00:00, 67.0MB/s]
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
import os

HOME = os.getcwd()

print(HOME)
# Out:
# /content

# %%
from IPython import display

from ultralytics import YOLO
from  IPython.display import display, Image

# %%
# %cd {HOME}

Image(filename = f'{HOME}/runs/detect/train/confusion_matrix_normalized.png' ,width=700)

# %%
#Charts displaying key metrics tracked by yolov8 with more emphasis on box loss and class loss

Image(filename = f'{HOME}/runs/detect/train/results.png' ,width=600)

# %%
#Visualizing the accuracy of the model in predicting various classes
Image(filename = f'{HOME}/runs/detect/train/F1_curve.png' ,width=600)

# %%
#Visualize some examples of model predictions on validation batch

Image(filename = f'{HOME}/runs/detect/train/val_batch0_pred.jpg' ,width=800)

# %%
#Visualize some examples of model predictions on validation batch

Image(filename = f'{HOME}/runs/detect/train/val_batch2_pred.jpg' ,width=800)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import locale
print(locale.getpreferredencoding())
# Out:
# ANSI_X3.4-1968

# %%
locale.getpreferredencoding = lambda: "UTF-8"

# %%
# !jupyter nbconvert --to html visdrone.ipynb
# Out:
# [NbConvertApp] Converting notebook visdrone.ipynb to html
# [NbConvertApp] Writing 3325576 bytes to visdrone.html
